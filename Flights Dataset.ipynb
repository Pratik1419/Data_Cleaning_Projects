# %%
# Possible palette values are:


# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r,  


# CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r,  


# OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r,  


# Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd,  


# PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r,  


# RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral,  


# Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd,  


# YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r,  


# bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix

# %% [markdown]
# Code Start Hear...

# %%
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
import seaborn as sns

# %%
flight_data = sns.load_dataset("flights")
flight_data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flight_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# CHECKING IF WE HAVE NULL VALUES ON THE DATAFRAME...

flight_data.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
# CHECKING IF WE HAVE ANY DUPLICATED VALUE ...

flight_data.duplicated().sum()
# Out:
# 0

# %%
flight_data.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
# Count of year of flight...
counts_year= flight_data["year"].value_counts()
counts_year
# Out:
# year
# 1949    12
# 1950    12
# 1951    12
# 1952    12
# 1953    12
# 1954    12
# 1955    12
# 1956    12
# 1957    12
# 1958    12
# 1959    12
# 1960    12
# Name: count, dtype: int64

# %%
# FIND HOW MANY PASSENGERS HAVE USED FLIGHT IN A MONTH

grouped_month = flight_data.groupby('month')['passengers'].sum().head()
print(grouped_month)
# Out:
# month
# Jan    2901
# Feb    2820
# Mar    3242
# Apr    3205
# May    3262
# Name: passengers, dtype: int64
# C:\Users\PRATIK MISHRA\AppData\Local\Temp\ipykernel_18236\1197451928.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_month = flight_data.groupby('month')['passengers'].sum().head()

# %%
# FIND THE MEAN VALUE OF THE PASSENGERS ARE USING FLIGHT IN A YEAR

grouped_year = flight_data.groupby('year')['passengers'].mean().round(2)
grouped_year
# Out:
# year
# 1949    126.67
# 1950    139.67
# 1951    170.17
# 1952    197.00
# 1953    225.00
# 1954    238.92
# 1955    284.00
# 1956    328.25
# 1957    368.42
# 1958    381.00
# 1959    428.33
# 1960    476.17
# Name: passengers, dtype: float64

# %%
# VISUALIZING OUR DATA OF MONTH OVER PASSENGERS ON THE FLIGHT...

sns.set(style = 'whitegrid')
sns.boxplot(hue='month',y='passengers', data = flight_data, palette='Paired', legend=False)
# Out:
# <Axes: ylabel='passengers'>

# %%
# VISUALIZING OUR DATA OF YEAR OVER PASSENGERS ON THE FLIGHT...
sns.set(style = 'whitegrid')
sns.boxplot(hue='year',y='passengers', data = flight_data, palette='Paired', legend=False)
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
# CREATING A PIVOT_TABLE FOR PASSENGER WITH THE INDEX OF MONTH AND COLUMNS
monthly_passengers = flight_data.pivot_table(values='passengers', index='month', columns='year')
sns.heatmap(monthly_passengers)
# Out:
# C:\Users\PRATIK MISHRA\AppData\Local\Temp\ipykernel_18236\1151657654.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   monthly_passengers = flight_data.pivot_table(values='passengers', index='month', columns='year')
# <Axes: xlabel='year', ylabel='month'>

# %%
# Creating  lineplot using both year and passengers

sns.lineplot(x='year', y='passengers', data=flight_data)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
# Creating  lineplot using both month and passengers...
sns.lineplot(x='month', y = 'passengers', data = flight_data)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
# Creating violinplot using both month and passengers...

sns.violinplot(x='month', hue='month', y='passengers', data = flight_data, palette='autumn_r', legend=False)
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %%
# # Creating lineplot using both month and passengers with grouping by year and months to find the mean ...

sns.lineplot(x='month', y='passengers', hue='year', data=flight_data.groupby(['year', 'month']).mean())
# Out:
# C:\Users\PRATIK MISHRA\AppData\Local\Temp\ipykernel_18236\639927963.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sns.lineplot(x='month', y='passengers', hue='year', data=flight_data.groupby(['year', 'month']).mean())
# <Axes: xlabel='month', ylabel='passengers'>

# %%
# Creating hisplot of passengers...

sns.histplot(data= flight_data,hue='year',x='passengers', bins=10, palette='PuBuGn_r', legend=False)
# Out:
# <Axes: xlabel='passengers', ylabel='Count'>
